# %%
import pandas as pd
import numpy as np

# %%
primary_df = pd.read_csv('primary-results.csv')

# %%
primary_df['candidate'].unique()
# Out:
# array(['Bernie Sanders', 'Hillary Clinton', 'Ben Carson', 'Donald Trump',
#        'John Kasich', 'Marco Rubio', 'Ted Cruz', ' Uncommitted',
#        "Martin O'Malley", 'Carly Fiorina', 'Chris Christie', 'Jeb Bush',
#        'Mike Huckabee', 'Rand Paul', 'Rick Santorum', ' No Preference'],
#       dtype=object)

# %%
pd.pivot_table(
    primary_df, 
    index=['state', 'party', 'candidate'], 
    values=['votes'], 
    aggfunc={'votes': np.sum}
)
# Out:
#                                             votes
# state         party      candidate
# Alabama       Democrat   Bernie Sanders     76399
#                          Hillary Clinton   309928
#               Republican Ben Carson         87517
#                          Donald Trump      371735
#                          John Kasich        37970
#                          Marco Rubio       159802
#                          Ted Cruz          180608
# Alaska        Democrat   Bernie Sanders       440
#                          Hillary Clinton       99
#               Republican Ben Carson          2401
#                          Donald Trump        7346
#                          John Kasich          892
#                          Marco Rubio         3318
#                          Ted Cruz            7973
# Arizona       Democrat   Bernie Sanders    163400
#                          Hillary Clinton   235697
#               Republican Donald Trump      249916
#                          John Kasich        53040
#                          Ted Cruz          132147
# Arkansas      Democrat   Bernie Sanders     64868
#                          Hillary Clinton   144580
#               Republican Ben Carson         23173
#                          Donald Trump      133144
#                          John Kasich        15098
#                          Marco Rubio       101235
#                          Ted Cruz          123873
# California    Democrat   Bernie Sanders   1502043
#                          Hillary Clinton  1940580
#               Republican Donald Trump     1174829
#                          John Kasich       176620
# ...                                           ...
# Vermont       Republican Marco Rubio        11778
#                          Ted Cruz            5929
# Virginia      Democrat   Bernie Sanders    275507
#                          Hillary Clinton   503358
#               Republican Ben Carson         60093
#                          Donald Trump      355960
#                          John Kasich        96519
#                          Marco Rubio       327042
#                          Ted Cruz          173193
# Washington    Democrat   Bernie Sanders     19159
#                          Hillary Clinton     7140
#               Republican Donald Trump      403003
#                          John Kasich        52129
#                          Ted Cruz           55719
# West Virginia Democrat   Bernie Sanders    123860
#                          Hillary Clinton    86354
#               Republican Donald Trump      156245
#                          John Kasich        13685
#                          Ted Cruz           18208
# Wisconsin     Democrat   Bernie Sanders    567936
#                          Hillary Clinton   432767
#               Republican Donald Trump      386370
#                          John Kasich       155200
#                          Ted Cruz          531129
# Wyoming       Democrat   Bernie Sanders       156
#                          Hillary Clinton      124
#               Republican Donald Trump          70
#                          John Kasich            0
#                          Marco Rubio          189
#                          Ted Cruz             644
#
# [290 rows x 1 columns]

# %%
primary_df['rank'] = primary_df.groupby(['county','party'])['votes'].rank(ascending=False)

# %%
primary_df[primary_df['county'] == 'Los Angeles']
# Out:
#            state state_abbreviation       county    fips       party  \
# 1385  California                 CA  Los Angeles  6037.0    Democrat
# 1386  California                 CA  Los Angeles  6037.0    Democrat
# 1519  California                 CA  Los Angeles  6037.0  Republican
# 1520  California                 CA  Los Angeles  6037.0  Republican
# 1521  California                 CA  Los Angeles  6037.0  Republican
#
#             candidate   votes  fraction_votes  rank
# 1385   Bernie Sanders  434656           0.420   2.0
# 1386  Hillary Clinton  590502           0.570   1.0
# 1519     Donald Trump  179130           0.698   1.0
# 1520      John Kasich   33559           0.131   2.0
# 1521         Ted Cruz   30775           0.120   3.0

# %%
primary_df_groupby = primary_df.groupby(['state','party','candidate']).sum()
del primary_df_groupby['fips']
del primary_df_groupby['fraction_votes']
primary_df_groupby.reset_index(inplace=True)
primary_df_groupby.head()
# Out:
#      state       party        candidate   votes    rank
# 0  Alabama    Democrat   Bernie Sanders   76399   555.0
# 1  Alabama    Democrat  Hillary Clinton  309928   266.0
# 2  Alabama  Republican       Ben Carson   87517   966.0
# 3  Alabama  Republican     Donald Trump  371735   390.0
# 4  Alabama  Republican      John Kasich   37970  1340.0

# %%
primary_df_groupby['rank'] = primary_df.groupby(['state','party'])['votes'].rank(ascending=False)

# %%
primary_df_groupby.head(7)
# Out:
#      state       party        candidate   votes   rank
# 0  Alabama    Democrat   Bernie Sanders   76399   92.0
# 1  Alabama    Democrat  Hillary Clinton  309928   42.0
# 2  Alabama  Republican       Ben Carson   87517   34.0
# 3  Alabama  Republican     Donald Trump  371735   13.0
# 4  Alabama  Republican      John Kasich   37970  118.0
# 5  Alabama  Republican      Marco Rubio  159802   37.0
# 6  Alabama  Republican         Ted Cruz  180608  116.0

# %%
pd.pivot_table(
    primary_df_groupby, 
    index=['state','party','candidate'],
    values=['rank','votes']
)
# Out:
#                                            rank    votes
# state         party      candidate
# Alabama       Democrat   Bernie Sanders    92.0    76399
#                          Hillary Clinton   42.0   309928
#               Republican Ben Carson        34.0    87517
#                          Donald Trump      13.0   371735
#                          John Kasich      118.0    37970
#                          Marco Rubio       37.0   159802
#                          Ted Cruz         116.0   180608
# Alaska        Democrat   Bernie Sanders    72.0      440
#                          Hillary Clinton  103.0       99
#               Republican Ben Carson        89.0     2401
#                          Donald Trump     124.0     7346
#                          John Kasich       39.0      892
#                          Marco Rubio      128.0     3318
#                          Ted Cruz          44.0     7973
# Arizona       Democrat   Bernie Sanders    58.0   163400
#                          Hillary Clinton   14.0   235697
#               Republican Donald Trump     109.0   249916
#                          John Kasich       32.0    53040
#                          Ted Cruz         114.0   132147
# Arkansas      Democrat   Bernie Sanders    84.0    64868
#                          Hillary Clinton  112.0   144580
#               Republican Ben Carson        74.0    23173
#                          Donald Trump     113.0   133144
#                          John Kasich       51.5    15098
#                          Marco Rubio      120.5   101235
#                          Ted Cruz          28.0   123873
# California    Democrat   Bernie Sanders   131.0  1502043
#                          Hillary Clinton   76.0  1940580
#               Republican Donald Trump     134.0  1174829
#                          John Kasich      119.0   176620
# ...                                         ...      ...
# Vermont       Republican Marco Rubio       24.0    11778
#                          Ted Cruz         192.0     5929
# Virginia      Democrat   Bernie Sanders    95.0   275507
#                          Hillary Clinton   74.0   503358
#               Republican Ben Carson       204.0    60093
#                          Donald Trump      82.0   355960
#                          John Kasich      265.0    96519
#                          Marco Rubio      160.0   327042
#                          Ted Cruz         165.0   173193
# Washington    Democrat   Bernie Sanders   107.0    19159
#                          Hillary Clinton   21.0     7140
#               Republican Donald Trump     193.0   403003
#                          John Kasich       75.0    52129
#                          Ted Cruz          59.0    55719
# West Virginia Democrat   Bernie Sanders   220.0   123860
#                          Hillary Clinton   91.0    86354
#               Republican Donald Trump     287.0   156245
#                          John Kasich      189.0    13685
#                          Ted Cruz         159.0    18208
# Wisconsin     Democrat   Bernie Sanders   235.0   567936
#                          Hillary Clinton  103.0   432767
#               Republican Donald Trump     292.5   386370
#                          John Kasich      207.0   155200
#                          Ted Cruz         173.0   531129
# Wyoming       Democrat   Bernie Sanders   201.0      156
#                          Hillary Clinton   76.5      124
#               Republican Donald Trump     278.0       70
#                          John Kasich      179.0        0
#                          Marco Rubio      132.0      189
#                          Ted Cruz         329.0      644
#
# [290 rows x 2 columns]

# %%
primary_df_groupby[primary_df_groupby['rank'] == 1]['candidate'].value_counts()
# Out:
# Ted Cruz    1
# Name: candidate, dtype: int64
