# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('alunos.xls')

# %%
df.groupby('NOME').aggregate({'NOTA':[np.min, np.mean, np.max]})

def notas_maiores_que_cinco(x):
    return x['NOTA'].sum() > 5

df.groupby('NOME').filter(notas_maiores_que_cinco)
# Out:
#                               NOME  NOTA        TURMA  \
# 0      AARON DE GEUS ROMEIRO ALVES   0.0       SIJ121
# 1      AARON DE GEUS ROMEIRO ALVES   0.0       SIJ121
# 2      AARON DE GEUS ROMEIRO ALVES   0.0       SIJ121
# 3      AARON DE GEUS ROMEIRO ALVES   0.0       SIJ121
# 4      AARON DE GEUS ROMEIRO ALVES   0.0       SIJ121
# 5      AARON DE GEUS ROMEIRO ALVES   0.0       SIJ121
# 6      AARON DE GEUS ROMEIRO ALVES   0.0  TADS121-03A
# 7      AARON DE GEUS ROMEIRO ALVES   0.0  TADS121-03B
# 8      AARON DE GEUS ROMEIRO ALVES   0.2       SIJ121
# 9      AARON DE GEUS ROMEIRO ALVES   1.7       SIJ121
# 10     AARON DE GEUS ROMEIRO ALVES   4.0       SIJ121
# 11     AARON DE GEUS ROMEIRO ALVES   5.3       SIJ121
# 12     AARON DE GEUS ROMEIRO ALVES   5.9       SIJ121
# 13     AARON DE GEUS ROMEIRO ALVES   6.0       SIJ121
# 14     AARON DE GEUS ROMEIRO ALVES   6.4       SIJ121
# 15     AARON DE GEUS ROMEIRO ALVES   6.5       SIJ121
# ...
